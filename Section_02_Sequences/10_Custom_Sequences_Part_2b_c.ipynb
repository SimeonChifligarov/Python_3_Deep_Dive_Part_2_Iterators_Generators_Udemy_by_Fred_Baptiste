# %% [markdown]
# ### Custom Sequences (Part 2b/c)

# %% [markdown]
# For this example we'll re-use the Polygon class from a previous lecture on extending sequences.
#
# We are going to consider a polygon as nothing more than a collection of points (and we'll stick to a 2-dimensional space).
#
# So, we'll need a `Point` class, but we're going to use our own custom class instead of just using a named tuple.
#
# We do this because we want to enforce a rule that our Point co-ordinates will be real numbers. We would not be able to use a named tuple to do that and we could end up with points whose `x` and `y` coordinates could be of any type.

# %% [markdown]
# First we'll need to see how we can test if a type is a numeric real type.
#
# We can do this by using the numbers module.

# %%
import numbers

# %% [markdown]
# This module contains certain base types for numbers that we can use, such as Number, Real, Complex, etc.

# %%
isinstance(10, numbers.Number)
# Out:
# True

# %%
isinstance(10.5, numbers.Number)
# Out:
# True

# %%
isinstance(1+1j, numbers.Number)
# Out:
# True

# %% [markdown]
# We will want our points to be real numbers only, so we can do it this way:

# %%
isinstance(1+1j, numbers.Real)
# Out:
# False

# %%
isinstance(10, numbers.Real)
# Out:
# True

# %%
isinstance(10.5, numbers.Real)
# Out:
# True

# %% [markdown]
# So now let's write our Point class. We want it to have these properties:
#
#   1. The `x` and `y` coordinates should be real numbers only
#   2. Point instances should be a sequence type so that we can unpack it as needed in the same way we were able to unpack the values of a named tuple.

# %%
class Point:
    def __init__(self, x, y):
        if isinstance(x, numbers.Real) and isinstance(y, numbers.Real):
            self._pt = (x, y)
        else:
            raise TypeError('Point co-ordinates must be real numbers.')
            
    def __repr__(self):
        return f'Point(x={self._pt[0]}, y={self._pt[1]})'
    
    def __len__(self):
        return 2
    
    def __getitem__(self, s):
        return self._pt[s]

# %% [markdown]
# Let's use our point class and make sure it works as intended:

# %%
p = Point(1, 2)

# %%
p
# Out:
# Point(x=1, y=2)

# %%
len(p)
# Out:
# 2

# %%
p[0], p[1]
# Out:
# (1, 2)

# %%
x, y = p

# %%
x, y
# Out:
# (1, 2)

# %% [markdown]
# Now, we can start creatiung our Polygon class, that will essentially be a mutable sequence of points making up the verteces of the polygon.

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        return f'Polygon({self._pts})'

# %% [markdown]
# Let's try it and see if everything is as we expect:

# %%
p = Polygon()

# %%
p
# Out:
# Polygon([])

# %%
p = Polygon((0,0), [1,1])

# %%
p
# Out:
# Polygon([Point(x=0, y=0), Point(x=1, y=1)])

# %%
p = Polygon(Point(0, 0), [1, 1])

# %%
p
# Out:
# Polygon([Point(x=0, y=0), Point(x=1, y=1)])

# %% [markdown]
# That seems to be working, but only one minor thing - our representation contains those square brackets which technically should not be there as the Polygon class init assumes multiple arguments, not a single iterable.
#
# So we should fix that:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join(self._pts)
        return f'Polygon({pts_str})'

# %% [markdown]
# But that still won't work, because the `join` method expects an iterable of **strings** - here we are passing it an iterable of `Point` objects:

# %%
p = Polygon((0,0), (1,1))

# %%
p
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\lib\pretty.py:420, in RepresentationPrinter.pretty(self, obj)
#     409                         return meth(obj, self, cycle)
#     410                 if (
#     411                     cls is not object
#     412                     # check if cls defines __repr__
#    (...)    418                     and callable(_safe_getattr(cls, "__repr__", None))
#     419                 ):
# --> 420                     return _repr_pprint(obj, self, cycle)
#     422     return _default_pprint(obj, self, cycle)
#     423 finally:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\lib\pretty.py:795, in _repr_pprint(obj, p, cycle)
#     793 """A pprint that just redirects to the normal repr function."""
#     794 # Find newlines and replace them with p.break_()
# --> 795 output = repr(obj)
#     796 lines = output.splitlines()
#     797 with p.group():
#
# Cell In[22], line 9, in Polygon.__repr__(self)
#       8 def __repr__(self):
# ----> 9     pts_str = ', '.join(self._pts)
#      10     return f'Polygon({pts_str})'
#
# TypeError: sequence item 0: expected str instance, Point found

# %% [markdown]
# So, let's fix that:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'

# %%
p = Polygon((0,0), (1,1))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1))

# %% [markdown]
# Ok, so now we can start making our Polygon into a sequence type, by implementing methods such as `__len__` and `__getitem__`:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]

# %% [markdown]
# Notice how we are simply delegating those methods to the ones supported by lists since we are storing our sequence of points internally using a list!

# %%
p = Polygon((0,0), Point(1,1), [2,2])

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0]
# Out:
# Point(x=0, y=0)

# %%
p[::-1]
# Out:
# [Point(x=2, y=2), Point(x=1, y=1), Point(x=0, y=0)]

# %% [markdown]
# Now let's implement concatenation (we'll skip repetition - wouldn't make much sense anyway):

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')

# %%
p1 = Polygon((0,0), (1,1))
p2 = Polygon((2,2), (3,3))
print(id(p1), p1)
print(id(p2), p2)
# Out:
# 1746576901520 Polygon(Point(x=0, y=0), Point(x=1, y=1))
# 1746576594960 Polygon(Point(x=2, y=2), Point(x=3, y=3))

# %%
result = p1 + p2

# %%
print(id(result), result)
# Out:
# 1746576596560 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %% [markdown]
# Now, let's handle in-place concatenation. Let's start by only allowing the RHS of the in-place concatenation to be another Polygon:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __add__(self, other):
        if isinstance(other, Polygon):
            new_pts = self._pts + other._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')
            
    def __iadd__(self, pt):
        if isinstance(pt, Polygon):
            self._pts = self._pts + pt._pts
            return self
        else:
            raise TypeError('can only concatenate with another Polygon')

# %%
p1 = Polygon((0,0), (1,1))
p2 = Polygon((2,2), (3,3))
print(id(p1), p1)
print(id(p2), p2)
# Out:
# 1746576902864 Polygon(Point(x=0, y=0), Point(x=1, y=1))
# 1746576597200 Polygon(Point(x=2, y=2), Point(x=3, y=3))

# %%
p1 += p2

# %%
print(id(p1), p1)
# Out:
# 1746576902864 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %% [markdown]
# So that worked, but this would not:

# %%
p1 = Polygon((0,0), (1,1))

# %%
p1 += [(2,2), (3,3)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 p1 += [(2,2), (3,3)]
#
# Cell In[37], line 30, in Polygon.__iadd__(self, pt)
#      28     return self
#      29 else:
# ---> 30     raise TypeError('can only concatenate with another Polygon')
#
# TypeError: can only concatenate with another Polygon

# %% [markdown]
# As you can see we get that type error. But we really should be able to handle appending any iterable of Points - and of course Points could also be specified as just iterables of length 2 containing numbers:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')
            
    def __iadd__(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
        return self

# %%
p1 = Polygon((0,0), (1,1))

# %%
p1 += [(2,2), (3,3)]

# %%
p1
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %% [markdown]
# Now let's implement some methods such as `append`, `extend` and `insert`:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')
            
    def __iadd__(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
        return self
    
    def append(self, pt):
        self._pts.append(Point(*pt))
        
    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
            
    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

# %% [markdown]
# Notice how we used almost the same code for `__iadd__` and `extend`?
# The only difference is that `__iadd__` returns the object, while `extend` does not - so let's clean that up a bit:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))
        
    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
    
    def __iadd__(self, pts):
        self.extend(pts)
        return self
    
    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

# %% [markdown]
# Now let's give all this a try:

# %%
p1 = Polygon((0,0), Point(1,1))
p2 = Polygon([2, 2], [3, 3])
print(id(p1), p1)
print(id(p2), p2)
# Out:
# 1746576904880 Polygon(Point(x=0, y=0), Point(x=1, y=1))
# 1746572380112 Polygon(Point(x=2, y=2), Point(x=3, y=3))

# %%
p1 += p2

# %%
print(id(p1), p1)
# Out:
# 1746576904880 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %% [markdown]
# That worked still, now let's see `append`:

# %%
p1
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3))

# %%
p1.append((4, 4))

# %%
p1
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4))

# %%
p1.append(Point(5,5))

# %%
print(id(p1), p1)
# Out:
# 1746576904880 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4), Point(x=5, y=5))

# %% [markdown]
# `append` seems to be working, now for `extend`:

# %%
p3 = Polygon((6,6), (7,7))

# %%
p1.extend(p3)

# %%
print(id(p1), p1)
# Out:
# 1746576904880 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4), Point(x=5, y=5), Point(x=6, y=6), Point(x=7, y=7))

# %%
p1.extend([(8,8), Point(9,9)])

# %%
print(id(p1), p1)
# Out:
# 1746576904880 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4), Point(x=5, y=5), Point(x=6, y=6), Point(x=7, y=7), Point(x=8, y=8), Point(x=9, y=9))

# %% [markdown]
# Now let's see if `insert` works as expected:

# %%
p1 = Polygon((0,0), (1,1), (2,2))

# %%
print(id(p1), p1)
# Out:
# 1746572071152 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p1.insert(1, (100, 100))

# %%
print(id(p1), p1)
# Out:
# 1746572071152 Polygon(Point(x=0, y=0), Point(x=100, y=100), Point(x=1, y=1), Point(x=2, y=2))

# %%
p1.insert(1, Point(50, 50))

# %%
print(id(p1), p1)
# Out:
# 1746572071152 Polygon(Point(x=0, y=0), Point(x=50, y=50), Point(x=100, y=100), Point(x=1, y=1), Point(x=2, y=2))

# %% [markdown]
# Now that we have that working, let's turn our attention to the `__setitem__` method so we can support index and slice assignments:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __setitem__(self, s, value):
        # value could be a single Point (or compatible type) for s an int
        # or it could be an iterable of Points if s is a slice
        # let's start by handling slices only first
        self._pts[s] = [Point(*pt) for pt in value]
            
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))
        
    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
    
    def __iadd__(self, pts):
        self.extend(pts)
        return self
    
    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

# %% [markdown]
# So, we are only handling slice assignments at this point, not assignments such as `p[0] = Point(0,0)`:

# %%
p = Polygon((0,0), (1,1), (2,2))
print(id(p), p)
# Out:
# 1746576905888 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0:2] = [(10, 10), (20, 20), (30, 30)]

# %%
print(id(p), p)
# Out:
# 1746576905888 Polygon(Point(x=10, y=10), Point(x=20, y=20), Point(x=30, y=30), Point(x=2, y=2))

# %% [markdown]
# So this seems to work fine. But this won't yet:

# %%
p[0] = Point(100, 100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 p[0] = Point(100, 100)
#
# Cell In[68], line 22, in Polygon.__setitem__(self, s, value)
#      18 def __setitem__(self, s, value):
#      19     # value could be a single Point (or compatible type) for s an int
#      20     # or it could be an iterable of Points if s is a slice
#      21     # let's start by handling slices only first
# ---> 22     self._pts[s] = [Point(*pt) for pt in value]
#
# TypeError: __main__.Point() argument after * must be an iterable, not int

# %% [markdown]
# If we look at the precise error, we see that our list comprehension is the cause of the error - we fail to correctly handle the case where the value passed in is not an iterable of Points...

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __setitem__(self, s, value):
        # value could be a single Point (or compatible type) for s an int
        # or it could be an iterable of Points if s is a slice
        # we could do this:
        if isinstance(s, int):
            self._pts[s] = Point(*value)
        else:
            self._pts[s] = [Point(*pt) for pt in value]
            
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))
        
    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
    
    def __iadd__(self, pts):
        self.extend(pts)
        return self
    
    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

# %% [markdown]
# This will now work as expected:

# %%
p = Polygon((0,0), (1,1), (2,2))
print(id(p), p)
# Out:
# 1746576906560 Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0] = Point(10, 10)

# %%
print(id(p), p)
# Out:
# 1746576906560 Polygon(Point(x=10, y=10), Point(x=1, y=1), Point(x=2, y=2))

# %% [markdown]
# What happens if we try to assign a single Point to a slice:

# %%
p[0:2] = Point(10, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 p[0:2] = Point(10, 10)
#
# Cell In[73], line 25, in Polygon.__setitem__(self, s, value)
#      23     self._pts[s] = Point(*value)
#      24 else:
# ---> 25     self._pts[s] = [Point(*pt) for pt in value]
#
# TypeError: __main__.Point() argument after * must be an iterable, not int

# %% [markdown]
# As expected this will not work. What about assigning an iterable of points to an index:

# %%
p[0] = [Point(10, 10), Point(20, 20)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 p[0] = [Point(10, 10), Point(20, 20)]
#
# Cell In[73], line 23, in Polygon.__setitem__(self, s, value)
#      18 def __setitem__(self, s, value):
#      19     # value could be a single Point (or compatible type) for s an int
#      20     # or it could be an iterable of Points if s is a slice
#      21     # we could do this:
#      22     if isinstance(s, int):
# ---> 23         self._pts[s] = Point(*value)
#      24     else:
#      25         self._pts[s] = [Point(*pt) for pt in value]
#
# Cell In[8], line 6, in Point.__init__(self, x, y)
#       4     self._pt = (x, y)
#       5 else:
# ----> 6     raise TypeError('Point co-ordinates must be real numbers.')
#
# TypeError: Point co-ordinates must be real numbers.

# %% [markdown]
# This works fine, but the error messages are a bit misleading - we probably should do something about that:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __setitem__(self, s, value):
        # we first should see if we have a single Point
        # or an iterable of Points in value
        try:
            rhs = [Point(*pt) for pt in value]
            is_single = False
        except TypeError:
            # not a valid iterable of Points
            # maybe a single Point?
            try:
                rhs = Point(*value)
                is_single = True
            except TypeError:
                # still no go
                raise TypeError('Invalid Point or iterable of Points')
        
        # reached here, so rhs is either an iterable of Points, or a Point
        # we want to make sure we are assigning to a slice only if we 
        # have an iterable of points, and assigning to an index if we 
        # have a single Point only
        if (isinstance(s, int) and is_single) \
            or isinstance(s, slice) and not is_single:
            self._pts[s] = rhs
        else:
            raise TypeError('Incompatible index/slice assignment')
                
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))
        
    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
    
    def __iadd__(self, pts):
        self.extend(pts)
        return self
    
    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))

# %% [markdown]
# So now let's see if we get better error messages:

# %%
p1 = Polygon((0,0), (1,1), (2,2))

# %%
p1[0:2] = (10,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 p1[0:2] = (10,10)
#
# Cell In[79], line 42, in Polygon.__setitem__(self, s, value)
#      40     self._pts[s] = rhs
#      41 else:
# ---> 42     raise TypeError('Incompatible index/slice assignment')
#
# TypeError: Incompatible index/slice assignment

# %%
p1[0] = [(0,0), (1,1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 p1[0] = [(0,0), (1,1)]
#
# Cell In[79], line 42, in Polygon.__setitem__(self, s, value)
#      40     self._pts[s] = rhs
#      41 else:
# ---> 42     raise TypeError('Incompatible index/slice assignment')
#
# TypeError: Incompatible index/slice assignment

# %% [markdown]
# And the allowed slice/index assignments work as expected:

# %%
p[0] = Point(100, 100)

# %%
p
# Out:
# Polygon(Point(x=100, y=100), Point(x=1, y=1), Point(x=2, y=2))

# %%
p[0:2] = [(0,0), (1,1), (2,2)]

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=2, y=2))

# %% [markdown]
# And if we try to replace with bad Point data:

# %%
p[0] = (0, 2+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 p[0] = (0, 2+2j)
#
# Cell In[73], line 23, in Polygon.__setitem__(self, s, value)
#      18 def __setitem__(self, s, value):
#      19     # value could be a single Point (or compatible type) for s an int
#      20     # or it could be an iterable of Points if s is a slice
#      21     # we could do this:
#      22     if isinstance(s, int):
# ---> 23         self._pts[s] = Point(*value)
#      24     else:
#      25         self._pts[s] = [Point(*pt) for pt in value]
#
# Cell In[8], line 6, in Point.__init__(self, x, y)
#       4     self._pt = (x, y)
#       5 else:
# ----> 6     raise TypeError('Point co-ordinates must be real numbers.')
#
# TypeError: Point co-ordinates must be real numbers.

# %% [markdown]
# We also get a better error message.

# %% [markdown]
# Lastly let's see how we would implement the `del` keyword and the `pop` method.

# %% [markdown]
# Recall how the `del` keyword works for a list:

# %%
l = [1, 2, 3, 4, 5]

# %%
del l[0]

# %%
l
# Out:
# [2, 3, 4, 5]

# %%
del l[0:2]

# %%
l
# Out:
# [4, 5]

# %%
del l[-1]

# %%
l
# Out:
# [4]

# %% [markdown]
# So, `del` works with indices (positive or negative) and slices too. We'll do the same:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __setitem__(self, s, value):
        # we first should see if we have a single Point
        # or an iterable of Points in value
        try:
            rhs = [Point(*pt) for pt in value]
            is_single = False
        except TypeError:
            # not a valid iterable of Points
            # maybe a single Point?
            try:
                rhs = Point(*value)
                is_single = True
            except TypeError:
                # still no go
                raise TypeError('Invalid Point or iterable of Points')
        
        # reached here, so rhs is either an iterable of Points, or a Point
        # we want to make sure we are assigning to a slice only if we 
        # have an iterable of points, and assigning to an index if we 
        # have a single Point only
        if (isinstance(s, int) and is_single) \
            or isinstance(s, slice) and not is_single:
            self._pts[s] = rhs
        else:
            raise TypeError('Incompatible index/slice assignment')
                
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))
        
    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
    
    def __iadd__(self, pts):
        self.extend(pts)
        return self
    
    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))
        
    def __delitem__(self, s):
        del self._pts[s]

# %%
p = Polygon(*zip(range(6), range(6)))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4), Point(x=5, y=5))

# %%
del p[0]

# %%
p
# Out:
# Polygon(Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4), Point(x=5, y=5))

# %%
del p[-1]

# %%
p
# Out:
# Polygon(Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4))

# %%
del p[0:2]

# %%
p
# Out:
# Polygon(Point(x=3, y=3), Point(x=4, y=4))

# %% [markdown]
# Now, we just have to implement `pop`:

# %%
class Polygon:
    def __init__(self, *pts):
        if pts:
            self._pts = [Point(*pt) for pt in pts]
        else:
            self._pts = []
            
    def __repr__(self):
        pts_str = ', '.join([str(pt) for pt in self._pts])
        return f'Polygon({pts_str})'
    
    def __len__(self):
        return len(self._pts)
    
    def __getitem__(self, s):
        return self._pts[s]
    
    def __setitem__(self, s, value):
        # we first should see if we have a single Point
        # or an iterable of Points in value
        try:
            rhs = [Point(*pt) for pt in value]
            is_single = False
        except TypeError:
            # not a valid iterable of Points
            # maybe a single Point?
            try:
                rhs = Point(*value)
                is_single = True
            except TypeError:
                # still no go
                raise TypeError('Invalid Point or iterable of Points')
        
        # reached here, so rhs is either an iterable of Points, or a Point
        # we want to make sure we are assigning to a slice only if we 
        # have an iterable of points, and assigning to an index if we 
        # have a single Point only
        if (isinstance(s, int) and is_single) \
            or isinstance(s, slice) and not is_single:
            self._pts[s] = rhs
        else:
            raise TypeError('Incompatible index/slice assignment')
                
    def __add__(self, pt):
        if isinstance(pt, Polygon):
            new_pts = self._pts + pt._pts
            return Polygon(*new_pts)
        else:
            raise TypeError('can only concatenate with another Polygon')

    def append(self, pt):
        self._pts.append(Point(*pt))
        
    def extend(self, pts):
        if isinstance(pts, Polygon):
            self._pts = self._pts + pts._pts
        else:
            # assume we are being passed an iterable containing Points
            # or something compatible with Points
            points = [Point(*pt) for pt in pts]
            self._pts = self._pts + points
    
    def __iadd__(self, pts):
        self.extend(pts)
        return self
    
    def insert(self, i, pt):
        self._pts.insert(i, Point(*pt))
        
    def __delitem__(self, s):
        del self._pts[s]
        
    def pop(self, i):
        return self._pts.pop(i)

# %%
p = Polygon(*zip(range(6), range(6)))

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=1, y=1), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4), Point(x=5, y=5))

# %%
p.pop(1)
# Out:
# Point(x=1, y=1)

# %%
p
# Out:
# Polygon(Point(x=0, y=0), Point(x=2, y=2), Point(x=3, y=3), Point(x=4, y=4), Point(x=5, y=5))
